# %%
## https://www.kaggle.com/shank885/knife-dataset?select=knife

# %%
pip install ludwig
# Out:
# ...
#   Created wheel for ludwig: filename=ludwig-0.2.2.7-py3-none-any.whl size=236250 sha256=daefad5f7d08831bf8f70bf333615366fb6c1825978f6eda71e052f0ed9d72f0
#   Stored in directory: c:\users\mavan\appdata\local\pip\cache\wheels\aa\95\1d\8443fca4a931882a5ceb162eba87482066ca08fb200d9faa82
# ...
#   Created wheel for absl-py: filename=absl_py-0.9.0-py3-none-any.whl size=121935 sha256=317ed5b38bfa93ca36a2bd9cbdd6a55c967c2e54699b9ed038678b51f7a9f83d
#   Stored in directory: c:\users\mavan\appdata\local\pip\cache\wheels\cc\af\1a\498a24d0730ef484019e007bb9e8cef3ac00311a672c049a3e
# ...
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4835 sha256=6c1c53ea06c922e1fec733848177fe20a833a05293ecced473263f7860ae7851
#   Stored in directory: c:\users\mavan\appdata\local\pip\cache\wheels\3f\e3\ec\8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
# ...

# %%
from ludwig.api import LudwigModel
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\MaVan\anaconda3\lib\site-packages\tensorflow_core\python\pywrap_tensorflow.py", line 58, in <module>
#     from tensorflow.python.pywrap_tensorflow_internal import *
#   File "C:\Users\MaVan\anaconda3\lib\site-packages\tensorflow_core\python\pywrap_tensorflow_internal.py", line 28, in <module>
#     _pywrap_tensorflow_internal = swig_import_helper()
#   File "C:\Users\MaVan\anaconda3\lib\site-packages\tensorflow_core\python\pywrap_tensorflow_internal.py", line 24, in swig_import_helper
#     _mod = imp.load_module('_pywrap_tensorflow_internal', fp, pathname, description)
#   File "C:\Users\MaVan\anaconda3\lib\imp.py", line 242, in load_module
#     return load_dynamic(name, filename, file)
#   File "C:\Users\MaVan\anaconda3\lib\imp.py", line 342, in load_dynamic
#     return _load(spec)
# ...

# %%
data_csv knife.csv
# Out:
#   File "<ipython-input-11-ba36295fe2a7>", line 1
#     data_csv knife.csv
#                  ^
# SyntaxError: invalid syntax

# %%
input_features:
        name: knife_path
        type: image
        encoder: stacked_cnn

output_features:
        name: class
        type: category
# Out:
#   File "<ipython-input-12-79a52d288dc2>", line 1
#     input_features:
#                    ^
# SyntaxError: invalid syntax
